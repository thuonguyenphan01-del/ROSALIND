# %% [markdown]
# F1=F2=1
# F3= F2 + 3*F1 = 1 + 1*3 =4;
# F4 = F3 + F2*3 = 4 + 3*1 =7
# F5= F4 + F3*3 = 7 + 4*3=19

# %%
def rabbit(n,k):
    F1=F2=1
    if n==1:
        return 1
    if n==2:
        return 1
    if n >=3:
        for i in range (3,n+1): 
            Fn = F2 + 3 *F1
            F1, F2 = F2, Fn # vòng 1 i=3 thì Fn=F2 + 3*F1 = 1+ 3*1 =4 gán F1=1, F2=4; vòng 2 i=4: Fn = 4 + 3*1=7 gán F1=4, F2=7
    return F2 
print(rabbit(36,3))
# Out:
# 3048504677680
