# %%
with open(r"C:\Users\ASUS\Downloads\rosalind_subs.txt", "r") as f:
    string1=f.readline().strip()
    string2=f.readline().strip()
#string1="GATATATGCATATACTT"
#tring2="ATAT"
index=[]
for i in range(len(string1)):
    if string2== string1[i:i+ len(string2)]:
        index.append(i+1)
print(index)
# Out:
# [34, 79, 113, 164, 188, 220, 295, 302, 320, 327, 334, 400, 407, 414, 421, 471, 478, 593, 635, 745, 752, 777, 839, 927]
